# %%
spark.sql("CREATE SCHEMA IF NOT EXISTS workspace.reinsurance_ifrs17_raw")

tables = spark.catalog.listTables("workspace.reinsurance_ifrs17_raw")
for t in tables:
    spark.sql(f"DROP TABLE IF EXISTS workspace.reinsurance_ifrs17_raw.{t.name}")

display(spark.sql("SHOW TABLES IN workspace.reinsurance_ifrs17_raw"))
